# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../data/players_and_transf.csv")
df = df.drop("Unnamed: 0",axis=1) # Delete index col

# %% [markdown]
# ### Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35812 entries, 0 to 35811
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            35812 non-null  object
#  1   club            35812 non-null  object
#  2   position        35812 non-null  object
#  3   apps            35812 non-null  object
#  4   mins            35812 non-null  int64
#  5   goals           35812 non-null  object
#  6   assists         35812 non-null  object
#  7   yel             35812 non-null  object
#  8   red             35812 non-null  object
#  9   shots           35812 non-null  object
#  10  ps%             35812 non-null  object
#  11  aerials_won     35812 non-null  object
#  12  motm            35812 non-null  object
#  13  rating          35812 non-null  float64
#  14  tackles         35792 non-null  object
#  15  interceptions   35792 non-null  object
#  16  fouls           35792 non-null  object
#  17  offsides_won    35792 non-null  object
#  18  clearances      35792 non-null  object
#  19  dribbled        35792 non-null  object
#  20  blocks          35792 non-null  object
#  21  own_goals       35792 non-null  object
#  22  key_passes      35792 non-null  object
#  23  dribblings      35792 non-null  object
#  24  fouled          35792 non-null  object
#  25  offsides        35792 non-null  object
#  26  dispossed       35792 non-null  object
#  27  bad_controls    35792 non-null  object
#  28  avg_passes      35782 non-null  object
#  29  crosses         35782 non-null  object
#  30  long_passes     35782 non-null  object
#  31  through_passes  35782 non-null  object
#  32  league          35812 non-null  object
#  33  season          35812 non-null  object
#  34  fee             8610 non-null   object
#  35  traded          35812 non-null  int64
# dtypes: float64(1), int64(2), object(33)
# memory usage: 9.8+ MB

# %%
df.describe(include="all")
# Out:
#           name   club position   apps          mins  goals assists    yel  \
# count    35812  35812    35812  35812  35812.000000  35812   35812  35812
# unique    9802    180       30    674           NaN     45      22     19
# top     Felipe  Genoa       FW   0(1)           NaN      -       -      -
# freq        25    441     8553   1806           NaN  18808   19229   9867
# mean       NaN    NaN      NaN    NaN   1307.884955    NaN     NaN    NaN
# std        NaN    NaN      NaN    NaN    994.575992    NaN     NaN    NaN
# min        NaN    NaN      NaN    NaN      1.000000    NaN     NaN    NaN
# 25%        NaN    NaN      NaN    NaN    365.000000    NaN     NaN    NaN
# 50%        NaN    NaN      NaN    NaN   1187.000000    NaN     NaN    NaN
# 75%        NaN    NaN      NaN    NaN   2140.000000    NaN     NaN    NaN
# max        NaN    NaN      NaN    NaN   3450.000000    NaN     NaN    NaN
#
#           red  shots    ps% aerials_won   motm        rating tackles  \
# count   35812  35812  35812       35812  35812  35812.000000   35792
# unique      6     66    691          92     22           NaN      62
# top         -      -    100           -      -           NaN       -
# freq    31082   6503    689        4623  23631           NaN    4851
# mean      NaN    NaN    NaN         NaN    NaN      6.647935     NaN
# std       NaN    NaN    NaN         NaN    NaN      0.385124     NaN
# min       NaN    NaN    NaN         NaN    NaN      3.770000     NaN
# 25%       NaN    NaN    NaN         NaN    NaN      6.380000     NaN
# 50%       NaN    NaN    NaN         NaN    NaN      6.650000     NaN
# 75%       NaN    NaN    NaN         NaN    NaN      6.900000     NaN
# max       NaN    NaN    NaN         NaN    NaN     10.000000     NaN
#
#        interceptions  fouls offsides_won clearances dribbled blocks own_goals  \
# count          35792  35792        35792      35792    35792  35792     35792
# unique            61     44           30        129       41     27         5
# top                -      -            -          -        -      -         -
# freq            5979   4720        23278       4641     5617  15172     34023
# mean             NaN    NaN          NaN        NaN      NaN    NaN       NaN
# std              NaN    NaN          NaN        NaN      NaN    NaN       NaN
# min              NaN    NaN          NaN        NaN      NaN    NaN       NaN
# 25%              NaN    NaN          NaN        NaN      NaN    NaN       NaN
# 50%              NaN    NaN          NaN        NaN      NaN    NaN       NaN
# 75%              NaN    NaN          NaN        NaN      NaN    NaN       NaN
# max              NaN    NaN          NaN        NaN      NaN    NaN       NaN
#
#        key_passes dribblings fouled offsides dispossed bad_controls  \
# count       35792      35792  35792    35792     35792        35792
# unique         43         59     52       28        51           53
# top             -          -      -        -         -            -
# freq         6970       7747   4164    20316      6728         7484
# mean          NaN        NaN    NaN      NaN       NaN          NaN
# std           NaN        NaN    NaN      NaN       NaN          NaN
# min           NaN        NaN    NaN      NaN       NaN          NaN
# 25%           NaN        NaN    NaN      NaN       NaN          NaN
# 50%           NaN        NaN    NaN      NaN       NaN          NaN
# 75%           NaN        NaN    NaN      NaN       NaN          NaN
# max           NaN        NaN    NaN      NaN       NaN          NaN
#
#        avg_passes crosses long_passes through_passes   league     season  \
# count       35782   35782       35782          35782    35812      35812
# unique        886      37         154             14        5         13
# top             3       -           -              -  Serie A  2021/2022
# freq          298   15487        3544          26973     7802       2926
# mean          NaN     NaN         NaN            NaN      NaN        NaN
# std           NaN     NaN         NaN            NaN      NaN        NaN
# min           NaN     NaN         NaN            NaN      NaN        NaN
# 25%           NaN     NaN         NaN            NaN      NaN        NaN
# 50%           NaN     NaN         NaN            NaN      NaN        NaN
# 75%           NaN     NaN         NaN            NaN      NaN        NaN
# max           NaN     NaN         NaN            NaN      NaN        NaN
#
#                   fee        traded
# count            8610  35812.000000
# unique            529           NaN
# top     loan transfer           NaN
# freq             2230           NaN
# mean              NaN      0.240422
# std               NaN      0.427346
# min               NaN      0.000000
# 25%               NaN      0.000000
# 50%               NaN      0.000000
# 75%               NaN      0.000000
# max               NaN      1.000000

# %%
df.head(10)
# Out:
#                  name           club position   apps  mins goals assists yel  \
# 0        Arjen Robben         Bayern       FW  18(6)  1779    16       6   1
# 1      Stefan Kieling     Leverkusen       FW     33  2924    21       5   3
# 2  Zvjezdan Misimovic      Wolfsburg       FW     31  2768    10      13   7
# 3          Edin Dzeko      Wolfsburg       FW  33(1)  3003    22       7   4
# 4     Claudio Pizarro  Werder Bremen       FW  23(3)  2130    16       2   4
# 5      Paolo Guerrero        Hamburg       FW   4(2)   415     4       -   1
# 6          Mesut Ozil  Werder Bremen   M(CLR)  29(2)  2601     9      13   2
# 7               Naldo  Werder Bremen     D(C)     31  2762     5       2   5
# 8          Toni Kroos     Leverkusen     M(C)  26(7)  2360     9       9   6
# 9             Raffael  Hertha Berlin       FW  30(1)  2654     7       4   9
#
#   red shots   ps% aerials_won motm  rating tackles interceptions fouls  \
# 0   -   3.4  80.2         0.4    8    8.18     0.6           0.5   0.9
# 1   -     3  72.4         2.1    6    7.79     1.2           0.7   2.5
# 2   -   2.4  77.5         0.2    8    7.74     1.9           0.6   1.5
# 3   -   4.5  70.7         0.7    6    7.73     0.5           0.1   1.9
# 4   -   2.6  75.5         0.4    2    7.63       1           0.7     2
# 5   -     3  84.5         0.7    1    7.63     1.3           0.2   3.7
# 6   -   2.2  82.5         0.1    6    7.62     0.7           0.8   0.7
# 7   -     2  83.1         1.3    6    7.59     2.7           3.7   1.4
# 8   -   2.2  82.2         0.2    5    7.59     1.4             1   0.9
# 9   -   2.4  84.1         0.3    5    7.56     1.9           1.4   1.2
#
#   offsides_won clearances dribbled blocks own_goals key_passes dribblings  \
# 0            -          -      0.7      -         -        1.8          4
# 1            -        0.3      0.5    0.1         -        1.6        1.1
# 2            -        0.2      1.2    0.1         -        3.3        1.5
# 3            -        0.9      0.2    0.1         -        1.1          2
# 4            -        0.7      0.4    0.2         -        1.3        1.2
# 5            -        0.5      0.2    0.3         -        1.8        1.5
# 6            -          -      0.7      -         -          3        2.3
# 7          1.5        3.3      0.7    0.6         -        0.4        0.7
# 8            -        0.3      0.8    0.1         -        2.4        1.2
# 9            -        0.3      1.1      -         -        2.3          3
#
#   fouled offsides dispossed bad_controls avg_passes crosses long_passes  \
# 0    2.2      0.3       2.1            -       34.3     1.5           2
# 1    3.1      1.8       2.2            -       32.5     0.2         0.4
# 2    2.1      0.3       3.1            -       51.1     2.5         5.7
# 3    1.7      1.6       2.9            -       19.5     0.2         1.1
# 4    1.2      1.4       3.1            -       24.2     0.1         0.8
# 5    2.3      0.7       4.2            -       32.2       -         1.2
# 6    1.4      0.5       2.9            -       34.9     2.1         1.4
# 7      1      0.1       0.3            -       50.8       -         3.7
# 8    2.2      0.1       0.9            -       37.2     1.5         2.8
# 9    2.4      0.3       2.9            -       39.5     1.6         2.3
#
#   through_passes      league     season      fee  traded
# 0            0.2  Bundesliga  2009/2010      NaN       0
# 1            0.1  Bundesliga  2009/2010      NaN       0
# 2            0.5  Bundesliga  2009/2010   €8.50m       1
# 3            0.1  Bundesliga  2009/2010      NaN       0
# 4              -  Bundesliga  2009/2010      NaN       0
# 5            0.2  Bundesliga  2009/2010      NaN       0
# 6            0.1  Bundesliga  2009/2010  €18.00m       1
# 7              -  Bundesliga  2009/2010      NaN       0
# 8            0.3  Bundesliga  2009/2010      NaN       0
# 9            0.1  Bundesliga  2009/2010      NaN       0

# %% [markdown]
# #### Actions:
#  * Add both values when apps is like x(y)
#
#  * Transform "-" in na
#
#  * Standarize the positions

# %%
# apps
df['apps'] = df['apps'].apply(lambda x: x.replace('(',' ').replace(')',''))
df['apps'] = df['apps'].apply(lambda x: x if len(x.split(' ')) <= 1 else int(x.split(' ')[0]) + int(x.split(' ')[1]) )

# %%
# - to na
df = df.replace('-',np.nan)

# %%
# Group the positions
df.position.value_counts()
# Out:
# FW            8553
# D(C)          3821
# M(C)          3563
# DMC           2720
# GK            2589
# M(L)          1788
# M(R)          1669
# M(CLR)        1521
# M(CR)          883
# Midfielder     876
# D(CR)          827
# Forward        772
# M(CL)          724
# D(CL)          717
# M(LR)          638
# D(R)           589
# D(L)           564
# AM(CLR)        482
# Defender       472
# AM(C)          326
# D(CLR)         314
# AM(LR)         300
# D(LR)          216
# AM(CL)         199
# AM(L)          198
# Goalkeeper     193
# AM(R)          162
# AM(CR)         132
# midfielder       3
# forward          1
# Name: position, dtype: int64

# %% [markdown]
# We will group the positions in 4 groups, goalkeepers, defenders, midfielders and forwards.

# %%
df['position'] = df['position'].str.upper()
forwards = ['FW','FORWARD']
goalkeepers = ['GK','GOALKEEPER']
defenders = df[df['position'].str.startswith('D')].position.unique()
def_midfielders = df[df['position'].str.startswith('M')].position.unique()
off_midfielders = df[df['position'].str.startswith('AM')].position.unique()
def_midfielders = np.delete(def_midfielders,0)
off_midfielders = np.append(off_midfielders,'M(CLR)')

# %%
# Check if there are not duplicities
print(len(df.position.unique()))
print(len(forwards)+len(goalkeepers)+len(defenders)+len(def_midfielders)+len(off_midfielders))
# Out:
# 28
# 28

# %%
# Category
df['position_cat'] = df['position'].apply(lambda x: 'Forward' if x in (forwards) else ('GoalKeeper' if x in (goalkeepers) else ('Defender' if x in (defenders) else ('Def_Midfielder' if x in (def_midfielders) else 'Off_Midfielder'))))
df['position_cat'] = df['position_cat'].astype('category')

# %%
# To category
to_cat = ['club','position','league','season','traded','fee']

for x in to_cat:
    df[x] = df[x].astype("category")

# %%
# To string
df['name'] = df['name'].astype("string")

# %%
# To float
to_float = df.select_dtypes(include="object").columns

for x in to_float:
    df[x] = df[x].astype("float32")
    
df['rating'] = df['rating'].astype('float32')

# %%
# To int
df['mins'] = df['mins'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35812 entries, 0 to 35811
# Data columns (total 37 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            35812 non-null  string
#  1   club            35812 non-null  category
#  2   position        35812 non-null  category
#  3   apps            35812 non-null  float32
#  4   mins            35812 non-null  int32
#  5   goals           17004 non-null  float32
#  6   assists         16583 non-null  float32
#  7   yel             25945 non-null  float32
#  8   red             4730 non-null   float32
#  9   shots           29309 non-null  float32
#  10  ps%             35504 non-null  float32
#  11  aerials_won     31189 non-null  float32
#  12  motm            12181 non-null  float32
#  13  rating          35812 non-null  float32
#  14  tackles         30941 non-null  float32
#  15  interceptions   29813 non-null  float32
#  16  fouls           31072 non-null  float32
#  17  offsides_won    12514 non-null  float32
#  18  clearances      31151 non-null  float32
#  19  dribbled        30175 non-null  float32
#  20  blocks          20620 non-null  float32
#  21  own_goals       1769 non-null   float32
#  22  key_passes      28822 non-null  float32
#  23  dribblings      28045 non-null  float32
#  24  fouled          31628 non-null  float32
#  25  offsides        15476 non-null  float32
#  26  dispossed       29064 non-null  float32
#  27  bad_controls    28308 non-null  float32
#  28  avg_passes      35576 non-null  float32
#  29  crosses         20295 non-null  float32
#  30  long_passes     32238 non-null  float32
#  31  through_passes  8809 non-null   float32
#  32  league          35812 non-null  category
#  33  season          35812 non-null  category
#  34  fee             7902 non-null   category
#  35  traded          35812 non-null  category
#  36  position_cat    35812 non-null  category
# dtypes: category(7), float32(28), int32(1), string(1)
# memory usage: 4.6 MB

# %%
df.isna().sum()
# Out:
# name                  0
# club                  0
# position              0
# apps                  0
# mins                  0
# goals             18808
# assists           19229
# yel                9867
# red               31082
# shots              6503
# ps%                 308
# aerials_won        4623
# motm              23631
# rating                0
# tackles            4871
# interceptions      5999
# fouls              4740
# offsides_won      23298
# clearances         4661
# dribbled           5637
# blocks            15192
# own_goals         34043
# key_passes         6990
# dribblings         7767
# fouled             4184
# offsides          20336
# dispossed          6748
# bad_controls       7504
# avg_passes          236
# crosses           15517
# long_passes        3574
# through_passes    27003
# league                0
# season                0
# fee               27910
# traded                0
# position_cat          0
# dtype: int64

# %% [markdown]
# We have a lot of nulls but don´t panic yet, we will deal with them once we got more information.

# %% [markdown]
# ### Exploration

# %%
df.describe()
# Out:
#                apps          mins         goals       assists           yel  \
# count  35812.000000  35812.000000  17004.000000  16583.000000  25945.000000
# mean      18.581482   1307.884955      3.699071      2.643128      3.648641
# std       11.470528    994.575992      4.105239      2.248306      2.619964
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        8.000000    365.000000      1.000000      1.000000      2.000000
# 50%       19.000000   1187.000000      2.000000      2.000000      3.000000
# 75%       29.000000   2140.000000      5.000000      3.000000      5.000000
# max       38.000000   3450.000000     50.000000     21.000000     18.000000
#
#                red         shots           ps%   aerials_won          motm  \
# count  4730.000000  29309.000000  35504.000000  31189.000000  12181.000000
# mean      1.114376      0.912734     76.633179      1.125613      1.945571
# std       0.345691      0.723156     10.876432      0.989510      1.590923
# min       1.000000      0.100000     11.100000      0.100000      1.000000
# 25%       1.000000      0.400000     71.699997      0.400000      1.000000
# 50%       1.000000      0.700000     78.199997      0.800000      1.000000
# 75%       1.000000      1.200000     83.500000      1.500000      2.000000
# max       5.000000      7.400000    100.000000      9.500000     25.000000
#
#              rating       tackles  interceptions         fouls  offsides_won  \
# count  35812.000000  30941.000000   29813.000000  31072.000000  12514.000000
# mean       6.647903      1.366223       1.134849      1.003982      0.417450
# std        0.385131      0.853162       0.851969      0.526561      0.356201
# min        3.770000      0.100000       0.100000      0.100000      0.100000
# 25%        6.380000      0.700000       0.400000      0.600000      0.100000
# 50%        6.650000      1.200000       1.000000      0.900000      0.300000
# 75%        6.900000      1.900000       1.600000      1.300000      0.600000
# max       10.000000      9.000000       9.000000      8.000000      6.000000
#
#          clearances      dribbled        blocks    own_goals    key_passes  \
# count  31151.000000  30175.000000  20620.000000  1769.000000  28822.000000
# mean       1.737840      0.661617      0.330770     1.067835      0.679698
# std        1.918905      0.445553      0.279289     0.277207      0.515491
# min        0.100000      0.100000      0.100000     1.000000      0.100000
# 25%        0.400000      0.300000      0.100000     1.000000      0.300000
# 50%        1.000000      0.600000      0.200000     1.000000      0.600000
# 75%        2.400000      0.900000      0.400000     1.000000      0.900000
# max       16.299999      6.000000      5.000000     4.000000      5.000000
#
#          dribblings        fouled      offsides     dispossed  bad_controls  \
# count  28045.000000  31628.000000  15476.000000  29064.000000  28308.000000
# mean       0.676838      0.883412      0.305648      0.836348      0.944159
# std        0.584791      0.576944      0.297092      0.613657      0.644774
# min        0.100000      0.100000      0.100000      0.100000      0.100000
# 25%        0.300000      0.500000      0.100000      0.400000      0.500000
# 50%        0.500000      0.800000      0.200000      0.700000      0.800000
# 75%        0.900000      1.200000      0.400000      1.100000      1.300000
# max        9.000000      6.000000      3.000000      9.000000      7.000000
#
#          avg_passes       crosses   long_passes  through_passes
# count  35576.000000  20295.000000  32238.000000     8809.000000
# mean      26.852507      0.471351      2.168877        0.159555
# std       15.077521      0.444523      2.188546        0.127325
# min        0.300000      0.100000      0.100000        0.100000
# 25%       15.500000      0.100000      0.700000        0.100000
# 50%       25.900000      0.300000      1.500000        0.100000
# 75%       36.000000      0.600000      2.900000        0.200000
# max      110.000000     10.000000     22.299999        1.500000

# %% [markdown]
# It looks like the null value mean a '0' because the minimum value in features like goals, assists etc is 1 and that is impossible, not all players score at least 1 goal.

# %% [markdown]
# #### Goals

# %%
df['goals'] = df['goals'].fillna(0)
df['goals_cat'] = np.where(df['goals'] == 0,0,1)

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale = 2)
sns.histplot(df,x='mins',hue='goals_cat')
plt.legend(title='Scored', loc='upper right', labels=['Yes','No'],fontsize=15,title_fontsize=20)

# %% [markdown]
# Here we can see that out theory can be true. The distribution of minutes is more concentrated around 0 when the player didn´t score. The ones that didn´t score but played a normal amount of minutes can be defendes or goalkeepers.

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale = 2)
sns.countplot(data=df, x="position_cat",hue='goals_cat',palette='Set1')
plt.legend(title='Scored', loc='upper right', labels=['No', 'Yes'],fontsize=15,title_fontsize=20)
plt.xlabel("Position")
# Out:
# Text(0.5, 0, 'Position')

# %% [markdown]
# We can say that a "-" means a 0. In the chart above we can see the clear differences between the positions and that goalkeepers always have a "-". Before switching all "-" in the dataframe to 0 we will evaluate the mins for each category as we did with goals. If the distribution is similar to the goals one we will make the replace.

# %%
test = df.copy()


for x in to_float:
    test[x] = test[x].fillna(0)
    test[x] = np.where(test[x] == 0,0,1)
    plt.figure(figsize=(20,10))
    sns.set(font_scale = 2)
    sns.histplot(test,x='mins',hue=x)
    plt.legend(title=x, loc='upper right', labels=['Yes', 'No'],fontsize=15,title_fontsize=20)
# Out:
# <ipython-input-22-dc876f490110>:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(20,10))

# %% [markdown]
# As we can see almost all features follow the same distribution based on whether the have a 0 or not. The ones that don´t follow this distrbution are ones like red cards, ps that is a % etc so they are totally justified. We can confidently fill the nulls with "0" in all features except for fee. that a null means no fee.

# %%
# remove goals_cat 
df = df.drop('goals_cat',axis=1)

for x in to_float:
    df[x] = df[x].fillna(0)
    
df.isna().sum()
# Out:
# name                  0
# club                  0
# position              0
# apps                  0
# mins                  0
# goals                 0
# assists               0
# yel                   0
# red                   0
# shots                 0
# ps%                   0
# aerials_won           0
# motm                  0
# rating                0
# tackles               0
# interceptions         0
# fouls                 0
# offsides_won          0
# clearances            0
# dribbled              0
# blocks                0
# own_goals             0
# key_passes            0
# dribblings            0
# fouled                0
# offsides              0
# dispossed             0
# bad_controls          0
# avg_passes            0
# crosses               0
# long_passes           0
# through_passes        0
# league                0
# season                0
# fee               27910
# traded                0
# position_cat          0
# dtype: int64

# %% [markdown]
# The goal of this project is to predict the churn in football players based on their stats so the feature fee seems useless for this pourpouse.

# %%
df = df.drop('fee',axis = 1)

# %% [markdown]
# #### Balance

# %%
df.traded.value_counts()
# Out:
# 0    27202
# 1     8610
# Name: traded, dtype: int64

# %%
sns.set(font_scale = 1)
df.traded.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# First thing I want to study is the minutes distribution of minutes in traded and non traded players. Because I am not sure if we should take players that didn´t play in consideration.

# %% [markdown]
# #### Split Test Train

# %% [markdown]
# I want to split test and train now because I don´t want to learn about data that supposly I don´t have.

# %%
df[['season','traded']].value_counts().to_frame().sort_values(by='season')
# Out:
#                      0
# season    traded
# 2009/2010 1        573
#           0       2137
# 2010/2011 1        648
#           0       2073
# 2011/2012 1        620
#           0       2126
# 2012/2013 0       2109
#           1        660
# 2013/2014 0       2052
#           1        707
# 2014/2015 0       1995
#           1        712
# 2015/2016 0       2065
#           1        713
# 2016/2017 0       2033
#           1        707
# 2017/2018 0       2048
#           1        659
# 2018/2019 0       1990
#           1        679
# 2019/2020 1        578
#           0       2170
# 2020/2021 1        598
#           0       2234
# 2021/2022 1        756
#           0       2170

# %% [markdown]
# I think ir will be funnier to get as test the last 2 seasons and to use the rest as test. I did the calculus and the traded of the last 2 seasons represent around the 16% percent of the total trades which is a good number having in considereation the small size of the dataframe.

# %%
train = df[~df['season'].isin(['2020/2021','2021/2022'])].copy()
test = df[df['season'].isin(['2020/2021','2021/2022'])].copy()

# %%
train.shape
# Out:
# (30054, 36)

# %%
test.shape
# Out:
# (5758, 36)

# %% [markdown]
# ### Study

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale = 2)
sns.histplot(data=train,x='mins',hue="traded",stat = 'density', shrink = 0.8, common_norm=False)
plt.legend(title='Traded', loc='upper right', labels=['Yes', 'No'],fontsize=15,title_fontsize=20)
plt.xlabel("Mins")
# Out:
# Text(0.5, 0, 'Mins')

# %% [markdown]
# That is suprising for me. The most part of the players that are traded didn´t have a lot of minutes last season which implicates that most part of trades are based on a bad performance. We will keep minutes since seems important.

# %% [markdown]
# We are facing an imbalaced dataset

# %% [markdown]
# #### Correlation

# %%
corr = train.corr()
plt.figure(figsize=(40,20))
sns.set(font_scale = 1.5)
sns.heatmap(corr,linewidth=.5,annot=True)
# Out:
# <AxesSubplot:>

# %%
def get_redundant_pairs(df):
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df.corr())
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
table = get_top_abs_correlations(train, 30).to_frame()
cm = sns.light_palette("green", as_cmap=True)
tb = table.style.background_gradient(cmap=cm)
tb
# Out:
# Top Absolute Correlations
# <style  type="text/css" >
# #T_144cb237_8253_11ed_9243_bc5ff45f4266row0_col0{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row1_col0{
#             background-color:  #76ba76;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row2_col0{
#             background-color:  #82c082;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row3_col0{
#             background-color:  #84c084;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row4_col0{
#             background-color:  #86c286;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row5_col0{
#             background-color:  #8fc68f;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row6_col0{
#             background-color:  #92c892;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row7_col0{
#             background-color:  #aed5ae;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row8_col0{
#             background-color:  #b4d8b4;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row9_col0,#T_144cb237_8253_11ed_9243_bc5ff45f4266row10_col0{
#             background-color:  #b8dab8;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row11_col0{
#             background-color:  #bddcbd;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row12_col0{
#             background-color:  #beddbe;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row13_col0{
#             background-color:  #c1dfc1;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row14_col0{
#             background-color:  #c5e0c5;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row15_col0{
#             background-color:  #c7e1c7;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row16_col0{
#             background-color:  #cbe4cb;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row17_col0{
#             background-color:  #d3e7d3;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row18_col0{
#             background-color:  #d4e8d4;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row19_col0{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row20_col0,#T_144cb237_8253_11ed_9243_bc5ff45f4266row21_col0{
#             background-color:  #d8ead8;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row22_col0{
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row23_col0{
#             background-color:  #dbebdb;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row24_col0{
#             background-color:  #dfeddf;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row25_col0{
#             background-color:  #e5f0e5;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row26_col0{
#             background-color:  #e6f1e6;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row27_col0{
#             background-color:  #e7f1e7;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row28_col0{
#             background-color:  #e8f2e8;
#             color:  #000000;
#         }#T_144cb237_8253_11ed_9243_bc5ff45f4266row29_col0{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }</style><table id="T_144cb237_8253_11ed_9243_bc5ff45f4266" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row0" class="row_heading level0 row0" >apps</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row0" class="row_heading level1 row0" >mins</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row0_col0" class="data row0 col0" >0.946963</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row1" class="row_heading level0 row1" >goals</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row1" class="row_heading level1 row1" >shots</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row1_col0" class="data row1 col0" >0.743943</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row2" class="row_heading level0 row2" >offsides_won</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row2" class="row_heading level1 row2" >clearances</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row2_col0" class="data row2 col0" >0.721849</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row3" class="row_heading level0 row3" >key_passes</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row3" class="row_heading level1 row3" >crosses</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row3_col0" class="data row3 col0" >0.719518</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row4" class="row_heading level0 row4" >clearances</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row4" class="row_heading level1 row4" >blocks</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row4_col0" class="data row4 col0" >0.714050</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row5" class="row_heading level0 row5" >assists</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row5" class="row_heading level1 row5" >key_passes</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row5_col0" class="data row5 col0" >0.699176</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row6" class="row_heading level0 row6" >tackles</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row6" class="row_heading level1 row6" >interceptions</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row6_col0" class="data row6 col0" >0.693567</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row7" class="row_heading level0 row7" >goals</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row7" class="row_heading level1 row7" >motm</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row7_col0" class="data row7 col0" >0.647121</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row8" class="row_heading level0 row8" >shots</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row8" class="row_heading level1 row8" >dispossed</th>
#                         <td id="T_144cb237_8253_11ed_9243_bc5ff45f4266row8_col0" class="data row8 col0" >0.634755</td>
#             </tr>
#             <tr>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level0_row9" class="row_heading level0 row9" >rating</th>
#                         <th id="T_144cb237_8253_11ed_9243_bc5ff45f4266level1_row9" class="row_heading level1 row9" >avg_passes</th>
#                         <td id="T_144cb237_8253_11ed_9

# %% [markdown]
# There is a lot of correlation between the variables. We should study the possibility of reduce the dimensionality.

# %% [markdown]
# ### Distribution

# %%
numeric = to_float.union(["rating","mins"])
for x in numeric:
    plt.figure(figsize=(20,10))
    sns.set(font_scale = 2)
    sns.histplot(train,x=x,hue="traded",stat="percent",common_norm=False)
    plt.legend(title="Traded", loc='upper right', labels=['Yes', 'No'],fontsize=15,title_fontsize=20)
# Out:
# <ipython-input-34-142743804d57>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(20,10))

# %%
cat  = df.select_dtypes(include="category").columns

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale = 2)
sns.countplot(data=train, x="position_cat",hue='traded',palette='Set1')
plt.legend(title='Scored', loc='upper right', labels=['No', 'Yes'],fontsize=15,title_fontsize=20)
plt.xlabel("Position")
# Out:
# Text(0.5, 0, 'Position')

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale = 2)
sns.countplot(data=train, x="league",hue='traded',palette='Set1')
plt.legend(title='Scored', loc='upper right', labels=['No', 'Yes'],fontsize=15,title_fontsize=20)
plt.xlabel("Position")
# Out:
# Text(0.5, 0, 'Position')
